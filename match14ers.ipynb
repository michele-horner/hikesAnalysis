# %%
# %run getDataFrames.ipynb
# %run scrapeColorado14ers.ipynb

import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from selenium import webdriver

def get14erMatches(all_trails_14ers,co_14ers):

    all_trails_df = all_trails_14ers[:][:]

    # all_trails_df.name

    fourteeners = co_14ers[:][:]

    # fourteeners.to_csv('co_fourteener_data.csv')

    # all_trails_df.to_csv('all_trails_14ers.csv')

    # all_trails_df.insert(0, 'name', all_trails_df.pop('name'))

    # fourteeners['name'] = fourteeners.name.str.replace('Peak','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('and','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('Mt.','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('Peak','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('Trail','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('Mountain','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('of','')
    # fourteeners['name'] =fourteeners.trail_name.str.replace('the','')


    # browser = webdriver.Chrome()
    # browser.get('https://www.14ers.com/php14ers/14ers.php')

#     r = 1
#     while r < 59:
#         trail = browser.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(r)+']/td[1]/div/a').text.strip()
#         r+=1
#         print(trail)




    fourteener_names = list(fourteeners.trail_name)
    all_trails_names = list(all_trails_df.name)

    fourteener_names

    mat2 = []

    for i in all_trails_names: #names in smaller dataset to compare and match
    #get closest match of `name` compared to larger data `member_names`
        mat2.append(process.extract(i, fourteener_names, limit=1))


    mat3 = []
    for mat in mat2:
        mat3.append(mat[0][0])

    print(mat3)

    fourteener_name_matches = pd.DataFrame()

    fourteener_name_matches['names'] = all_trails_names

    fourteener_name_matches['matches2'] = mat3
    all_trails_df['matches'] = mat3
    print(fourteener_name_matches)
#     fourteeners = fourteeners.merge(fourteener_name_matches, left_on = 'trail_name', right_on = 'matches2')

    # fourteeners = fourteeners.drop_duplicates(subset = ['names'])
    
    # all_trails_df = all_trails_df.reset_index(drop = True)
    # print(all_trails_df)
    # print(fourteeners)
    all_trails_merge = all_trails_df.merge(fourteeners[['peak_name','trail_name','class_num','elevation_ft','rank','exposure','rockfall','route-finding','commitment']], left_on = 'matches', right_on = 'trail_name')
    all_trails_merge = all_trails_merge.set_index('name')
    # all_trails_merge = all_trails_merge.drop(columns = ['names'])
    return all_trails_merge

# %%
# Out:
#                                                name_x        ID  \
# 0                                 Quandary Peak Trail  10009879
# 1                              Grays and Torreys Peak  10240976
# 2                            North Mount Elbert Trail  10016676
# 3   The Decalibron: Mounts Democrat, Cameron, Linc...  10028367
# 4     The Keyhole and Longs Peak via Longs Peak Trail  10112141
# ..                                                ...       ...
# 84       Harvard Lakes, Mount Columbia, Mount Harvard  10351577
# 85                     Sunshine Peak (Northwest Face)  10351828
# 86       Mount Harvard via Frenchman Creek Trail 1457  10344041
# 87                   Uncompahgre and Matterhorn Peaks  10351818
# 88                       Mount Lindsey Trail [CLOSED]  10111784
#
#                                                  slug  popularity   type  \
# 0               trail/us/colorado/quandary-peak-trail     51.9924  trail
# 1            trail/us/colorado/grays-and-torreys-peak     41.4504  trail
# 2       trail/us/colorado/north-mount-elbert-trail--3     35.8681  trail
# 3   trail/us/colorado/the-decalibron-mounts-democr...     34.4271  trail
# 4   trail/us/colorado/the-keyhole-and-longs-peak-t...     30.1902  trail
# ..                                                ...         ...    ...
# 84  trail/us/colorado/harvard-lakes-mount-columbia...      6.6964  trail
# 85     trail/us/colorado/sunshine-peak-northwest-face      6.4976  trail
# 86  trail/us/colorado/mount-harvard-via-frenchman-...      6.3378  trail
# 87  trail/us/colorado/uncompahgre-and-matterhorn-p...      6.0557  trail
# 88              trail/us/colorado/mount-lindsey-trail      2.4968  trail
#
#                                  _geoloc     length  elevation_gain  \
# 0   {'lat': 39.38559, 'lng': -106.06186}  10621.644       1013.7648
# 1   {'lat': 39.66112, 'lng': -105.78426}  13035.654       1103.9856
# 2   {'lat': 39.15158, 'lng': -106.41249}  16737.136       1361.8464
# 3   {'lat': 39.32743, 'lng': -106.12935}  11265.380        955.8528
# 4   {'lat': 40.27212, 'lng': -105.55682}  23818.232       1535.8872
# ..                                   ...        ...             ...
# 84  {'lat': 38.86445, 'lng': -106.23865}  30255.592       2445.7152
# 85   {'lat': 37.93696, 'lng': -107.4608}  11909.116       1110.9960
# 86  {'lat': 38.93645, 'lng': -106.19427}  29129.054       1899.8184
# 87  {'lat': 38.02267, 'lng': -107.49118}  25910.374       1760.8296
# 88  {'lat': 37.62488, 'lng': -105.47128}  12713.786       1113.7392
#
#    difficulty_rating route_type  ...        objectID  \
# 0                  5          O  ...  trail-10009879
# 1                  5          O  ...  trail-10240976
# 2                  7          O  ...  trail-10016676
# 3                  5          L  ...  trail-10028367
# 4                  5          O  ...  trail-10112141
# ..               ...        ...  ...             ...
# 84                 5          O  ...  trail-10351577
# 85                 7          O  ...  trail-10351828
# 86                 5          O  ...  trail-10344041
# 87                 7          O  ...  trail-10351818
# 88                 5          O  ...  trail-10111784
#
#                       name_y         class elevation_ft  rank      exposure  \
# 0                     Quary        Class 1        14271    13           Low
# 1           Grays   Torreys        Class 1        14275     9           Low
# 2                     Elbert       Class 1        14438     1           Low
# 3   The Crestones  Humboldt        Class 3        14299     7          High
# 4   The Crestones  Humboldt        Class 3        14299     7          High
# ..                       ...           ...          ...   ...           ...
# 84        Harvard   Columbia       Class 2        14424     3      Moderate
# 85      Redcloud   Sunshine        Class 2        14043    46      Moderate
# 86        Harvard   Columbia       Class 2        14424     3      Moderate
# 87              Uncompahgre        Class 2        14318     6      Moderate
# 88                   Lindsey  Easy Class 3        14057    43  Considerable
#
#         rockfall  route-finding    commitment  \
# 0            Low            Low           Low
# 1            Low            Low           Low
# 2            Low            Low           Low
# 3   Considerable           High  Considerable
# 4   Considerable           High  Considerable
# ..           ...            ...           ...
# 84      Moderate            Low      Moderate
# 85      Moderate            Low           Low
# 86      Moderate            Low      Moderate
# 87  Considerable       Moderate      Moderate
# 88  Considerable   Considerable      Moderate
#
#                              matches
# 0                     [(Quary , 54)]
# 1           [(Grays   Torreys , 95)]
# 2                    [( Elbert, 90)]
# 3   [(The Crestones  Humboldt , 86)]
# 4   [(The Crestones  Humboldt , 86)]
# ..                               ...
# 84       [( Harvard   Columbia, 86)]
# 85      [(Redcloud   Sunshine , 86)]
# 86       [( Harvard   Columbia, 86)]
# 87              [(Uncompahgre , 90)]
# 88                  [( Lindsey, 90)]
#
# [89 rows x 56 columns]
