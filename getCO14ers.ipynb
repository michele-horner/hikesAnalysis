# %%
from selenium import webdriver
import re
from bs4 import BeautifulSoup
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def getallCO14erData():
    
    url_path = list(range(10001,10054))+list(range(10063,10067))

    name = []
    class_num = []
    exposure = []
    rockfall = []
    route_finding = []
    commitment= []
    elevation_ft =[]
    rank = []
    peak_name = []
    i = 1
    r = 0
    urls14ers = []

    while r < 57:
        urls14ers.append('https://www.14ers.com/routelist.php?peakid='+str(url_path[r]))
        r += 1

    browser = webdriver.Chrome()

    for link in urls14ers:

        browser.get(link)

        fourteen = BeautifulSoup(browser.page_source, 'html.parser')

        name.append(fourteen.find('h1').text.split('| ')[0].strip())

        rank.append(i)

        fourteen.find('h1').text.split('| ')[0].strip()

        # print(name)
        # class_num.append(browser.find_element_by_xpath('//*[@id="routeResults"]/tbody/tr[2]/td[6]/span').text)
        # print(class_num)


        risks = fourteen.find(id = 'routeriskinfo_1').text


        risks_spl = re.split('Exposure:|Rockfall| Potential:|Route-Finding: |Commitment:',risks)

        exposure.append(risks_spl[1].strip())
        rockfall.append(risks_spl[3].strip())
        route_finding.append(risks_spl[4].strip())
        commitment.append(risks_spl[5].strip())

        i += 1
        # print(rockfall)

    fourteener_df_1 = pd.DataFrame(list(zip(name, rank, exposure, rockfall, route_finding, commitment)), \
                                 columns = ['trail_name','rank','exposure','rockfall','route-finding','commitment'])

    fourteener_df_1

    driver = webdriver.Chrome()
    driver.get('https://www.14ers.com/routes.php')
    n = 1
    elevation_ft = []
    peak_name = []
    class_num = []
    while n <58:
        elevation_ft.append(int(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[6]').text.replace("'","").replace(',','')))
        peak_name.append(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[1]/div/a').text.strip())
        class_num.append(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[3]/span[2]').text.strip())
        n+=1

    fourteener_df_2 = pd.DataFrame(list(zip(peak_name,elevation_ft,class_num)), \
                                 columns = ['peak_name', 'elevation_ft','class_num'])


    peaks = list(fourteener_df_2.peak_name)
    trails = list(fourteener_df_1.trail_name)

    peaks = [s.replace('Peak','') for s in peaks]
    peaks = [m.replace('Mt.','') for m in peaks]
    # fourteeners['name'] =fourteeners.trail_name.str.replace('and','')
        # fourteeners['name'] =fourteeners.trail_name.str.replace('Mt.','')

    mat = []

    for i in peaks: #names in smaller dataset to compare and match
    #get closest match of `name` compared to larger data `member_names`
        mat.append(process.extract(i, trails, limit=1))

    matched = []
    for m in mat:
        matched.append(m[0][0])

    fourteener_name_matches = pd.DataFrame()

    fourteener_name_matches['trails'] = matched

    fourteener_name_matches['peak_matches'] = fourteener_df_2.peak_name

    fourteener_df_2['trail_matches'] = matched

    # fourteener_df_1 = fourteener_df_1.drop(columns = 'matches')
    fourteener_df_1 = fourteener_df_1.drop_duplicates(subset = 'trail_name')

    matched_14er_df = fourteener_df_2.merge(fourteener_df_1, right_on = 'trail_name', left_on = 'trail_matches')

    matched_14er_df = matched_14er_df.drop(columns = 'trail_matches')

    return matched_14er_df

# %%
# Out:
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_39160/3810130311.py:73: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   elevation_ft.append(int(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[6]').text.replace("'","").replace(',','')))
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_39160/3810130311.py:74: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   peak_name.append(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[1]/div/a').text.strip())
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_39160/3810130311.py:75: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   class_num.append(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[3]/span[2]').text.strip())

# %%
m14
# Out:
#                 peak_name  elevation_ft          class_num  \
# 0              Mt. Elbert         14438            Class 1
# 1             Mt. Massive         14427            Class 2
# 2             Mt. Harvard         14424            Class 2
# 3            Mt. Columbia         14075            Class 2
# 4             Blanca Peak         14350  Difficult Class 2
# 5        Ellingwood Point         14057  Difficult Class 2
# 6        Little Bear Peak         14041            Class 4
# 7           La Plata Peak         14344            Class 2
# 8        Uncompahgre Peak         14318            Class 2
# 9           Crestone Peak         14299            Class 3
# 10        Crestone Needle         14196            Class 3
# 11          Humboldt Peak         14068            Class 2
# 12            Mt. Lincoln         14293            Class 2
# 13            Mt. Cameron         14248            Class 2
# 14              Mt. Bross         14178            Class 2
# 15           Mt. Democrat         14154            Class 2
# 16             Grays Peak         14275            Class 1
# 17           Torreys Peak         14272            Class 2
# 18            Castle Peak         14274  Difficult Class 2
# 19         Conundrum Peak         14037  Difficult Class 2
# 20          Quandary Peak         14272            Class 1
# 21             Mt. Antero         14271            Class 2
# 22              Mt. Evans         14268            Class 2
# 23          Mt. Bierstadt         14066            Class 2
# 24             Longs Peak         14259            Class 3
# 25             Mt. Wilson         14256            Class 4
# 26         El Diente Peak         14175            Class 3
# 27            Wilson Peak         14021            Class 3
# 28            Mt. Shavano         14230            Class 2
# 29        Tabeguache Peak         14158            Class 2
# 30            Mt. Belford         14202            Class 2
# 31             Mt. Oxford         14158            Class 2
# 32      Missouri Mountain         14071            Class 2
# 33          Mt. Princeton         14200            Class 2
# 34               Mt. Yale         14200            Class 2
# 35        Kit Carson Peak         14167       Easy Class 3
# 36       Challenger Point         14086  Difficult Class 2
# 37            Maroon Peak         14163            Class 3
# 38           Pyramid Peak         14029            Class 4
# 39      North Maroon Peak         14022            Class 4
# 40           Mt. Sneffels         14155       Easy Class 3
# 41           Capitol Peak         14138            Class 4
# 42             Pikes Peak         14109            Class 1
# 43      Snowmass Mountain         14105            Class 3
# 44            Windom Peak         14089  Difficult Class 2
# 45              Mt. Eolus         14087            Class 3
# 46          Sunlight Peak         14061            Class 4
# 47            North Eolus         14042            Class 3
# 48           Handies Peak         14058            Class 1
# 49            Mt. Lindsey         14055       Easy Class 3
# 50           Culebra Peak         14053            Class 2
# 51            Mt. Sherman         14043            Class 2
# 52          Redcloud Peak         14037            Class 2
# 53          San Luis Peak         14023            Class 1
# 54        Wetterhorn Peak         14021            Class 3
# 55  Mt. of the Holy Cross         14007            Class 2
# 56             Huron Peak         14006            Class 2
#
#                                      trail_name  rank      exposure  \
# 0                                    Mt. Elbert     1           Low
# 1                                   Mt. Massive     2      Moderate
# 2                  Mt. Harvard and Mt. Columbia     3      Moderate
# 3                  Mt. Harvard and Mt. Columbia     3      Moderate
# 4            Blanca, Ellingwood and Little Bear     4           Low
# 5            Blanca, Ellingwood and Little Bear     4           Low
# 6            Blanca, Ellingwood and Little Bear     4           Low
# 7                                 La Plata Peak     5      Moderate
# 8                              Uncompahgre Peak     6      Moderate
# 9               The Crestones and Humboldt Peak     7          High
# 10              The Crestones and Humboldt Peak     7          High
# 11              The Crestones and Humboldt Peak     7          High
# 12         Lincoln, Democrat, Cameron and Bross     8      Moderate
# 13         Lincoln, Democrat, Cameron and Bross     8      Moderate
# 14         Lincoln, Democrat, Cameron and Bross     8      Moderate
# 15         Lincoln, Democrat, Cameron and Bross     8      Moderate
# 16                  Grays Peak and Torreys Peak     9           Low
# 17                  Grays Peak and Torreys Peak     9           Low
# 18               Castle Peak and Conundrum Peak    12  Considerable
# 19               Castle Peak and Conundrum Peak    12  Considerable
# 20                                Quandary Peak    13           Low
# 21                                   Mt. Antero    10      Moderate
# 22                          Evans and Bierstadt    14           Low
# 23                          Evans and Bierstadt    14           Low
# 24                                   Longs Peak    15          High
# 25  Mt. Wilson, Wilson Peak, and El Diente Peak    16           Low
# 26  Mt. Wilson, Wilson Peak, and El Diente Peak    16           Low
# 27  Mt. Wilson, Wilson Peak, and El Diente Peak    16           Low
# 28              Mt. Shavano and Tabeguache Peak    17      Moderate
# 29              Mt. Shavano and Tabeguache Peak    17      Moderate
# 30                 Belford, Oxford and Missouri    18           Low
# 31                 Belford, Oxford and Missouri    18           Low
# 32                 Belford, Oxford and Missouri    18           Low
# 33                                Mt. Princeton    20      Moderate
# 34                                     Mt. Yale    21      Moderate
# 35         Kit Carson Peak and Challenger Point    23           Low
# 36         Kit Carson Peak and Challenger Point    23           Low
# 37                Maroon Bells and Pyramid Peak    24          High
# 38                Maroon Bells and Pyramid Peak    24          High
# 39                Maroon Bells and Pyramid Peak    24          High
# 40                                 Mt. Sneffels    27  Considerable
# 41                                 Capitol Peak    29          High
# 42                                   Pikes Peak    30           Low
# 43                            Snowmass Mountain    31          High
# 44    Mt. Eolus, Windom Peak, and Sunlight Peak    32           Low
# 45    Mt. Eolus, Windom Peak, and Sunlight Peak    32           Low
# 46    Mt. Eolus, Windom Peak, and Sunlight Peak    32           Low
# 47    Mt. Eolus, Windom Peak, and Sunlight Peak    32           Low
# 48                                 Handies Peak    40      Moderate
# 49                                  Mt. Lindsey    43  Considerable
# 50                                 Culebra Peak    41      Moderate
# 51                                  Mt. Sherman    45      Moderate
# 52              Redcloud Peak and Sunshine Peak    46      Moderate
# 53                                San Luis Peak    50           Low
# 54                              Wetterhorn Peak    49          High
# 55                        Mt. of the Holy Cross    51      Moderate
# 56                                   Huron Peak    52      Moderate
#
#         rockfall route-finding    commitment
# 0            Low           Low           Low
# 1       Moderate      Moderate      Moderate
# 2       Moderate           Low      Moderate
# 3       Moderate           Low      Moderate
# 4            Low           Low           Low
# 5            Low           Low           Low
# 6            Low           Low           Low
# 7       Moderate           Low      Moderate
# 8   Considerable      Moderate      Moderate
# 9   Considerable          High  Considerable
# 10  Considerable          High  Considerable
# 11  Considerable          High  Considerable
# 12      Moderate           Low           Low
# 13      Moderate           Low           Low
# 14      Moderate           Low           Low
# 15      Moderate           Low           Low
# 16           Low           Low           Low
# 17           Low           Low           Low
# 18  Considerable  Considerable  Considerable
# 19  Considerable  Considerable  Considerable
# 20           Low           Low           Low
# 21      Moderate           Low      Moderate
# 22      Moderate           Low           Low
# 23      Moderate           Low           Low
# 24  Considerable  Considerable          High
# 25           Low           Low           Low
# 26           Low           Low           Low
# 27           Low           Low           Low
# 28      Moderate           Low      Moderate
# 29      Moderate           Low      Moderate
# 30      Moderate           Low      Moderate
# 31      Moderate           Low      Moderate
# 32      Moderate           Low      Moderate
# 33      Moderate           Low      Moderate
# 34      Moderate           Low      Moderate
# 35           Low           Low           Low
# 36           Low           Low           Low
# 37          High       Extreme       Extreme
# 38          High       Extreme       Extreme
# 39          High       Extreme       Extreme
# 40  Considerable      Moderate      Moderate
# 41          High          High       Extreme
# 42           Low           Low      Moderate
# 43  Considerable  Considerable          High
# 44           Low           Low           Low
# 45           Low           Low           Low
# 46           Low           Low           Low
# 47           Low           Low           Low
# 48           Low           Low           Low
# 49  Considerable  Considerable      Moderate
# 50      Moderate      Moderate      Moderate
# 51      Moderate           Low           Low
# 52      Moderate           Low           Low
# 53           Low           Low           Low
# 54  Considerable  Considerable  Considerable
# 55      Moderate      Moderate  Considerable
# 56      Moderate           Low           Low
