# %%
from selenium import webdriver
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
# url = 'https://www.14ers.com/routelist.php?peakid=10002'

# %%
def get14erData()

    url_path = list(range(10001,10053))

    name = []
    class_num = []
    exposure = []
    rockfall = []
    route_finding = []
    commitment= []
    elevation_ft =[]
    rank = []
    i = 1
    r = 0
    urls14ers = []

    while r < 52:
        urls14ers.append('https://www.14ers.com/routelist.php?peakid='+str(url_path[r]))
        r += 1

    browser = webdriver.Chrome()

    for link in urls14ers:

        browser.get(link)

        fourteen = BeautifulSoup(browser.page_source, 'html.parser')

        name.append(fourteen.find('h1').text.split('| ')[0].strip())

        rank.append(i)

        fourteen.find('h1').text.split('| ')[0].strip()

        # print(name)
        class_num.append(browser.find_element_by_xpath('//*[@id="routeResults"]/tbody/tr[2]/td[6]/span').text)
        # print(class_num)


        risks = fourteen.find(id = 'routeriskinfo_1').text


        risks_spl = re.split('Exposure:|Rockfall| Potential:|Route-Finding: |Commitment:',risks)

        exposure.append(risks_spl[1].strip())
        rockfall.append(risks_spl[3].strip())
        route_finding.append(risks_spl[4].strip())
        commitment.append(risks_spl[5].strip())

        i += 1
        # print(rockfall)

    driver = webdriver.Chrome()
    driver.get('https://www.14ers.com/routes.php')
    n = 1

    while n <53:
        elevation_ft.append(int(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[6]').text.replace("'","").replace(',','')))
        n+=1

    fourteener_df = pd.DataFrame(list(zip(name, class_num, elevation_ft, rank, exposure, rockfall, route_finding, commitment)), \
                                 columns = ['name','class','elevation_ft','rank','exposure','rockfall','route-finding','commitment'])

    return fourteener_df
# Out:
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_25286/1084658279.py:34: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   class_num.append(browser.find_element_by_xpath('//*[@id="routeResults"]/tbody/tr[2]/td[6]/span').text)
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_25286/1084658279.py:56: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   elevation_ft.append(int(driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[6]').text.replace("'","").replace(',','')))
#                                            name              class  \
# 0                                    Mt. Elbert            Class 1
# 1                                   Mt. Massive            Class 2
# 2                  Mt. Harvard and Mt. Columbia            Class 2
# 3            Blanca, Ellingwood and Little Bear            Class 1
# 4                                 La Plata Peak            Class 2
# 5                              Uncompahgre Peak            Class 2
# 6               The Crestones and Humboldt Peak            Class 3
# 7          Lincoln, Democrat, Cameron and Bross            Class 2
# 8                   Grays Peak and Torreys Peak            Class 1
# 9                                    Mt. Antero            Class 2
# 10                  Grays Peak and Torreys Peak            Class 1
# 11               Castle Peak and Conundrum Peak  Difficult Class 2
# 12                                Quandary Peak            Class 1
# 13                          Evans and Bierstadt            Class 2
# 14                                   Longs Peak            Class 3
# 15  Mt. Wilson, Wilson Peak, and El Diente Peak            Class 1
# 16              Mt. Shavano and Tabeguache Peak            Class 2
# 17                 Belford, Oxford and Missouri            Class 2
# 18              The Crestones and Humboldt Peak            Class 3
# 19                                Mt. Princeton            Class 2
# 20                                     Mt. Yale            Class 2
# 21         Lincoln, Democrat, Cameron and Bross            Class 2
# 22         Kit Carson Peak and Challenger Point            Class 1
# 23                Maroon Bells and Pyramid Peak            Class 3
# 24              Mt. Shavano and Tabeguache Peak            Class 2
# 25                 Belford, Oxford and Missouri            Class 2
# 26                                 Mt. Sneffels       Easy Class 3
# 27         Lincoln, Democrat, Cameron and Bross            Class 2
# 28                                 Capitol Peak            Class 4
# 29                                   Pikes Peak            Class 1
# 30                            Snowmass Mountain            Class 3
# 31    Mt. Eolus, Windom Peak, and Sunlight Peak            Class 1
# 32    Mt. Eolus, Windom Peak, and Sunlight Peak            Class 1
# 33         Kit Carson Peak and Challenger Point            Class 1
# 34                 Mt. Harvard and Mt. Columbia            Class 2
# 35                 Belford, Oxford and Missouri            Class 2
# 36              The Crestones and Humboldt Peak            Class 3
# 37                          Evans and Bierstadt            Class 2
# 38    Mt. Eolus, Windom Peak, and Sunlight Peak            Class 1
# 39                                 Handies Peak            Class 1
# 40                                 Culebra Peak            Class 2
# 41           Blanca, Ellingwood and Little Bear            Class 1
# 42                                  Mt. Lindsey       Easy Class 3
# 43           Blanca, Ellingwood and Little Bear            Class 1
# 44                                  Mt. Sherman            Class 2
# 45              Redcloud Peak and Sunshine Peak            Class 2
# 46                Maroon Bells and Pyramid Peak            Class 3
# 47  Mt. Wilson, Wilson Peak, and El Diente Peak            Class 1
# 48                              Wetterhorn Peak            Class 3
# 49                                San Luis Peak            Class 1
# 50                        Mt. of the Holy Cross            Class 2
# 51                                   Huron Peak            Class 2
#
#     elevation_ft  rank      exposure      rockfall route-finding    commitment
# 0          14438     1           Low           Low           Low           Low
# 1          14427     2      Moderate      Moderate      Moderate      Moderate
# 2          14424     3      Moderate      Moderate           Low      Moderate
# 3          14350     4           Low           Low           Low           Low
# 4          14344     5      Moderate      Moderate           Low      Moderate
# 5          14318     6      Moderate  Considerable      Moderate      Moderate
# 6          14299     7          High  Considerable          High  Considerable
# 7          14293     8      Moderate      Moderate           Low           Low
# 8          14275     9           Low           Low           Low           Low
# 9          14274    10      Moderate      Moderate           Low      Moderate
# 10         14272    11           Low           Low           Low           Low
# 11         14272    12  Considerable  Considerable  Considerable  Considerable
# 12         14271    13           Low           Low           Low           Low
# 13         14268    14           Low      Moderate           Low           Low
# 14         14259    15          High  Considerable  Considerable          High
# 15         14256    16           Low           Low           Low           Low
# 16         14248    17      Moderate      Moderate           Low      Moderate
# 17         14230    18           Low      Moderate           Low      Moderate
# 18         14202    19          High  Considerable          High  Considerable
# 19         14200    20      Moderate      Moderate           Low      Moderate
# 20         14200    21      Moderate      Moderate           Low      Moderate
# 21         14196    22      Moderate      Moderate           Low           Low
# 22         14178    23           Low           Low           Low           Low
# 23         14175    24          High          High       Extreme       Extreme
# 24         14167    25      Moderate      Moderate           Low      Moderate
# 25         14163    26           Low      Moderate           Low      Moderate
# 26         14158    27  Considerable  Considerable      Moderate      Moderate
# 27         14158    28      Moderate      Moderate           Low           Low
# 28         14155    29          High          High          High       Extreme
# 29         14154    30           Low           Low           Low      Moderate
# 30         14138    31          High  Considerable  Considerable          High
# 31         14109    32           Low           Low           Low           Low
# 32         14105    33           Low           Low           Low           Low
# 33         14089    34           Low           Low           Low           Low
# 34         14087    35      Moderate      Moderate           Low      Moderate
# 35         14086    36           Low      Moderate           Low      Moderate
# 36         14075    37          High  Considerable          High  Considerable
# 37         14071    38           Low      Moderate           Low           Low
# 38         14068    39           Low           Low           Low           Low
# 39         14066    40      Moderate           Low           Low           Low
# 40         14061    41      Moderate      Moderate      Moderate      Moderate
# 41         14058    42           Low           Low           Low           Low
# 42         14057    43  Considerable  Considerable  Considerable      Moderate
# 43         14055    44           Low           Low           Low           Low
# 44         14053    45      Moderate      Moderate           Low           Low
# 45         14043    46      Moderate      Moderate           Low           Low
# 46         14042    47          High          High       Extreme       Extreme
# 47         14041    48           Low           Low           Low           Low
# 48         14037    49          High  Considerable  Considerable  Considerable
# 49         14037    50           Low           Low           Low           Low
# 50         14029    51      Moderate      Moderate      Moderate  Considerable
# 51         14023    52      Moderate      Moderate           Low           Low

# %%
# Out:
# /var/folders/pp/c1yvb96j3mz428csxccvjgk00000gn/T/ipykernel_25286/4128760837.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="peakTable"]/tbody/tr['+str(n)+']/td[6]').text
# "14,438'"
